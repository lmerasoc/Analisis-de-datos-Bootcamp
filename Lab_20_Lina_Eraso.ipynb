# %% [markdown]
# <a href="https://colab.research.google.com/github/lmerasoc/Analisis-de-datos-Bootcamp/blob/main/Lab_20_Lina_Eraso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJERCICIO 1

# %%
import pandas as pd;
import numpy as np;
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b5eeaa1b-3f40-4e49-81f1-d0724a36ef0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5eeaa1b-3f40-4e49-81f1-d0724a36ef0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('datos_financieros.csv')
print(df.count())
print(df.head(20))
# Out:
# Edad                    1000
# Genero                  1000
# Historial_Crediticio    1000
# Salario_Anual            800
# Deuda                    850
# dtype: int64
#     Edad     Genero Historial_Crediticio  Salario_Anual     Deuda
# 0     56  Masculino                Bueno       41857.04   7266.60
# 1     69  Masculino              Regular       37189.53   8641.72
# 2     46  Masculino                Bueno       39960.48  18367.26
# 3     32   Femenino              Regular            NaN  16702.31
# 4     60  Masculino                Bueno            NaN   3502.09
# 5     25  Masculino                 Malo            NaN       NaN
# 6     38  Masculino              Regular       26773.20  14056.98
# 7     56   Femenino                 Malo       27491.67   4258.68
# 8     36   Femenino              Regular       43281.94  14093.89
# 9     40  Masculino                 Malo       35562.30  17689.66
# 10    28  Masculino                Bueno            NaN   4387.28
# ...

# %%
print(df.info())
print(df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Edad                  1000 non-null   int64
#  1   Genero                1000 non-null   object
#  2   Historial_Crediticio  1000 non-null   object
#  3   Salario_Anual         800 non-null    float64
#  4   Deuda                 850 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB
# None
#               Edad     Genero Historial_Crediticio  Salario_Anual  \
# count   1000.00000       1000                 1000     800.000000
# unique         NaN          2                    3            NaN
# top            NaN  Masculino                Bueno            NaN
# freq           NaN        524                  344            NaN
# mean      43.81900        NaN                  NaN   30594.115225
# ...

# %%
#Valores nulos
print(df.isnull().sum())
# Out:
# Edad                      0
# Genero                    0
# Historial_Crediticio      0
# Salario_Anual           200
# Deuda                   150
# dtype: int64

# %%
#Duplicated
print("Datos duplicados:",df.duplicated().sum())
print(df.duplicated())
# Out:
# Datos duplicados: 4
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#Llenar datos nulos
df1=df
df1['Salario_Anual'] = df1['Salario_Anual'].fillna(df1['Salario_Anual'].mean())
df1['Edad'] = df1['Edad'].fillna(df1['Edad'].mean())
print(df1.isnull().sum())
print(df1.count())
# Out:
# Edad                      0
# Genero                    0
# Historial_Crediticio      0
# Salario_Anual             0
# Deuda                   150
# dtype: int64
# Edad                    1000
# Genero                  1000
# Historial_Crediticio    1000
# Salario_Anual           1000
# Deuda                    850
# dtype: int64

# %%
#Eliminar datos
df2 = df1.dropna()
print(df2.isnull().sum())
print(df2.count())
# Out:
# Edad                    0
# Genero                  0
# Historial_Crediticio    0
# Salario_Anual           0
# Deuda                   0
# dtype: int64
# Edad                    850
# Genero                  850
# Historial_Crediticio    850
# Salario_Anual           850
# Deuda                   850
# dtype: int64

# %%
#Eliminar duplicados
df3 = df2.drop_duplicates()
df4=df3
print("Datos duplicados:",df4.duplicated().sum())
print(df3.count())
# Out:
# Datos duplicados: 0
# Edad                    850
# Genero                  850
# Historial_Crediticio    850
# Salario_Anual           850
# Deuda                   850
# dtype: int64

# %%
print(df4.info())
print(df4.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 850 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Edad                  850 non-null    int64
#  1   Genero                850 non-null    object
#  2   Historial_Crediticio  850 non-null    object
#  3   Salario_Anual         850 non-null    float64
#  4   Deuda                 850 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.8+ KB
# None
#               Edad     Genero Historial_Crediticio  Salario_Anual  \
# count   850.000000        850                  850     850.000000
# unique         NaN          2                    3            NaN
# top            NaN  Masculino                Bueno            NaN
# freq           NaN        445                  296            NaN
# mean     44.095294        NaN                  NaN   30700.642631
# ...

# %%
#exportar
df4.to_csv('datos_financieros_limpio', index=False)
print(df4)
from google.colab import files
files.download('datos_financieros_limpio')
# Out:
#      Edad     Genero Historial_Crediticio  Salario_Anual     Deuda
# 0      56  Masculino                Bueno   41857.040000   7266.60
# 1      69  Masculino              Regular   37189.530000   8641.72
# 2      46  Masculino                Bueno   39960.480000  18367.26
# 3      32   Femenino              Regular   30594.115225  16702.31
# 4      60  Masculino                Bueno   30594.115225   3502.09
# ..    ...        ...                  ...            ...       ...
# 995    60   Femenino                 Malo   30594.115225  17445.57
# 996    64  Masculino                 Malo   32072.670000  21357.25
# 997    62   Femenino                 Malo   30693.440000   7978.01
# 998    35  Masculino                 Malo   30594.115225  12457.15
# 999    55  Masculino                 Malo   31768.210000  12848.80
#
# [850 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#graficar
plt.figure(figsize=(10, 6))
plt.scatter(df4['Edad'], df4['Deuda'], color='green',alpha=0.5,label='Datos')
sns.regplot(x='Edad', y='Deuda', data=df4, scatter=False, color='red', label='Línea de tendencia')
plt.xlabel('Edad')
plt.ylabel('Deuda')
plt.title('Relación entre Edad y deuda')
plt.grid(True)
plt.legend()
plt.show()

# %%
#graficar 2
plt.figure(figsize=(10, 6))
plt.scatter(df4['Salario_Anual'], df4['Deuda'], color='blue',alpha=0.5,label='Datos')
sns.regplot(x='Salario_Anual', y='Deuda', data=df4, scatter=False, color='red', label='Línea de tendencia')
plt.xlabel('Salario')
plt.ylabel('Deuda')
plt.title('Relación entre salario y deuda')
plt.grid(True)
plt.legend()
plt.show()

# %%
#grafico barras _ 3
# Contar cuántos clientes hay por cada tipo de historial
conteo = df4['Historial_Crediticio'].value_counts().reset_index()
conteo.columns = ['Historial_Crediticio', 'Cantidad']
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.barplot(data=conteo, x='Historial_Crediticio', y='Cantidad', color='skyblue', width=0.6)
plt.title('Historial crediticio')
plt.xlabel('Historial crediticios')
plt.ylabel('Cantidad de clientes')
plt.tight_layout()
plt.show()

# %%
#CODIGO PROFE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Visualizacion personalizada
plt.figure(figsize=(10, 6))
plt.scatter(df4['Edad'], df4['Deuda'], c='green', alpha=0.5)
plt.title('Relación entre Edad y Deuda', fontsize=15)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Deuda', fontsize=12)
plt.grid(True)
# Añadir una linea de tendencia
z = np.polyfit(df4['Edad'], df4['Deuda'], 1)
p = np.poly1d(z)
plt.plot(df4['Edad'], p(df4['Edad']), color='red', label='Tendencia')
plt.legend()
plt.tight_layout()
plt.show()
print()
# Grafica de barras
plt.figure(figsize=(8, 6))
df4['Historial_Crediticio'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribución del Historial Crediticio', fontsize=15)
plt.xlabel('Historial Crediticio', fontsize=12)
plt.ylabel('Cantidad de Clientes', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Si el coeficiente cuadrático (z2[0]) es menor a 0.01, no tendrás una curva visible clara.
# Simula una curva "falsa" solo para ver la forma

z_fake = [0.05, -2, 130]  # Coeficientes inventados
p_fake = np.poly1d(z_fake)

x = np.sort(df_salud['Edad'])
y = df_salud['Glucosa']

plt.figure(figsize=(10, 6))
plt.scatter(df_salud['Edad'], y, alpha=0.5)
plt.plot(x, p_fake(x), color='orange', linewidth=2, label='Curva simulada')
plt.title('Simulación de tendencia curvada')
plt.xlabel('Edad')
plt.ylabel('Glucosa')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()





plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-e9070c5a4873> in <cell line: 0>()
#       5 p_fake = np.poly1d(z_fake)
#       6
# ----> 7 x = np.sort(df_salud['Edad'])
#       8 y = df_salud['Glucosa']
#       9
#
# NameError: name 'df_salud' is not defined

# %% [markdown]
# EJERCICIO 2

# %%
import pandas as pd;
import numpy as np;
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-462f2b0b-8671-445f-a266-e0efacc374cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-462f2b0b-8671-445f-a266-e0efacc374cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('datos_salud_glu.csv')
print(df.count())
print(df.head(20))
# Out:
# Edad                       1000
# Genero                     1000
# Glucosa                     800
# IMC                         850
# Antecedentes_Familiares    1000
# dtype: int64
#     Edad     Genero  Glucosa   IMC Antecedentes_Familiares
# 0     56  Masculino    120.7  25.7                      No
# 1     69  Masculino      NaN  31.7                      No
# 2     46   Femenino      NaN   NaN                      No
# 3     32  Masculino    105.4  30.0                      Si
# 4     60  Masculino      NaN  24.7                      Si
# 5     25   Femenino     99.2  22.0                      No
# 6     78  Masculino    150.7  32.4                      Si
# 7     38  Masculino     28.6  21.5                      Si
# 8     56  Masculino    150.4  26.7                      No
# 9     75  Masculino    148.9  28.8                      No
# 10    36  Masculino      NaN  29.2                      No
# 11    40   Femenino     49.6  19.2                      Si
# ...

# %%
print(df.info())
print(df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Edad                     1000 non-null   int64
#  1   Genero                   1000 non-null   object
#  2   Glucosa                  800 non-null    float64
#  3   IMC                      850 non-null    float64
#  4   Antecedentes_Familiares  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB
# None
#                Edad     Genero     Glucosa         IMC Antecedentes_Familiares
# count   1000.000000       1000  800.000000  850.000000                    1000
# unique          NaN          2         NaN         NaN                       2
# top             NaN  Masculino         NaN         NaN                      No
# freq            NaN        523         NaN         NaN                     506
# ...

# %%
#Valores nulos
print(df.isnull().sum())
#Duplicated
print("Datos duplicados:",df.duplicated().sum())
print(df.duplicated())
# Out:
# Edad                         0
# Genero                       0
# Glucosa                    200
# IMC                        150
# Antecedentes_Familiares      0
# dtype: int64
# Datos duplicados: 3
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#Llenar datos nulos
df1=df
df1['Glucosa'] = df1['Glucosa'].fillna(df1['Glucosa'].mean())
df1['IMC'] = df1['IMC'].fillna(df1['IMC'].mean())
print(df1.isnull().sum())
print(df1.count())
# Out:
# Edad                       0
# Genero                     0
# Glucosa                    0
# IMC                        0
# Antecedentes_Familiares    0
# dtype: int64
# Edad                       1000
# Genero                     1000
# Glucosa                    1000
# IMC                        1000
# Antecedentes_Familiares    1000
# dtype: int64

# %%
#Eliminar datos
df2 = df1.dropna()
print(df2.isnull().sum())
print(df2.count())
# Out:
# Edad                       0
# Genero                     0
# Glucosa                    0
# IMC                        0
# Antecedentes_Familiares    0
# dtype: int64
# Edad                       1000
# Genero                     1000
# Glucosa                    1000
# IMC                        1000
# Antecedentes_Familiares    1000
# dtype: int64

# %%
#verificacion
print(df2.info())
print(df2.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Edad                     1000 non-null   int64
#  1   Genero                   1000 non-null   object
#  2   Glucosa                  1000 non-null   float64
#  3   IMC                      1000 non-null   float64
#  4   Antecedentes_Familiares  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB
# None
#                Edad     Genero      Glucosa          IMC  \
# count   1000.000000       1000  1000.000000  1000.000000
# unique          NaN          2          NaN          NaN
# top             NaN  Masculino          NaN          NaN
# freq            NaN        523          NaN          NaN
# mean      49.857000        NaN   110.284875    25.380588
# std       18.114267        NaN    27.453640     4.833754
# ...

# %%
#exportar
df2.to_csv('datos_salud glu_limpios.csv', index=False)
print(df2)
from google.colab import files
files.download('datos_salud glu_limpios.csv')
# Out:
#      Edad     Genero     Glucosa        IMC Antecedentes_Familiares
# 0      56  Masculino  120.700000  25.700000                      No
# 1      69  Masculino  110.284875  31.700000                      No
# 2      46   Femenino  110.284875  25.380588                      No
# 3      32  Masculino  105.400000  30.000000                      Si
# 4      60  Masculino  110.284875  24.700000                      Si
# ..    ...        ...         ...        ...                     ...
# 995    18  Masculino   66.800000  25.380588                      No
# 996    35   Femenino   95.200000  34.200000                      Si
# 997    49   Femenino   69.700000  27.900000                      Si
# 998    64  Masculino   92.600000  21.000000                      No
# 999    66   Femenino  135.600000  25.380588                      Si
#
# [1000 rows x 5 columns]

# %%
#Codigo profe
# 3. Visualización personalizada
# Relación entre Edad y Niveles de Glucosa.
plt.figure(figsize=(10, 6))
plt.scatter(df2['Edad'], df2['Glucosa'], c='blue', alpha=0.5)
plt.title('Relación entre Edad y Niveles de Glucosa', fontsize=15)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Niveles de Glucosa', fontsize=12)
plt.grid(True)

# Añadir una línea de tendencia

z = np.polyfit(df2['Edad'], df2['Glucosa'], 1)
p = np.poly1d(z)
plt.plot(df2['Edad'], p(df2['Edad']), color='red', label='Tendencia')
plt.legend()


plt.tight_layout()
plt.show()
print()

# Crear el gráfico de barras de la columna 'Antecedentes_Familiares'
plt.figure(figsize=(8, 6))
df2['Antecedentes_Familiares'].value_counts().plot(kind='bar',	color='green', edgecolor='black')

# Personalización del gráfico
plt.title('Distribución de Antecedentes Familiares de Diabetes', fontsize=15)
plt.xlabel('Antecedentes Familiares', fontsize=12)
plt.ylabel('Cantidad de Pacientes', fontsize=12)

# Mostrar el gráfico
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()

# %%
print(df2.groupby('Antecedentes_Familiares')['Glucosa'].mean())
# Out:
# Antecedentes_Familiares
# No    110.293610
# Si    110.275928
# Name: Glucosa, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df2, x='Antecedentes_Familiares', y='Glucosa', edgecolor='black', width=0.6)

# Personalización
plt.title('Promedio de Glucosa según Antecedentes Familiares', fontsize=15)
plt.xlabel('Antecedentes Familiares (Sí / No)', fontsize=12)
plt.ylabel('Promedio de Niveles de Glucosa', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
